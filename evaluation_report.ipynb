# %%
import pandas as pd

# %%
df=pd.read_csv("budget_rag_evaluation_report.csv")
df
# Out:
#                                           user_input  \
# 0  What are the seven high-speed rail corridors m...
# 1  What are the proposals for AYUSH and Ayurveda ...
# 2                        What is the FAST-DS scheme?
# 3  What are the three 'kartavyas' that inspired t...
#
#                                   retrieved_contexts  \
# 0  ['9  \n \nthrough a challenge mode with a refo...
# 1  ['12  \n \n58. I propose to (i) set up 3 new A...
# 2  ['\uf0b7 It is proposed that any amount which ...
# 3  ['Budget.  \n8. Our Government’s ‘Sankalp’ is ...
#
#                                             response  \
# 0  - Mumbai-Pune\n- Pune-Hyderabad\n- Hyderabad-B...
# 1  - Set up 3 new All India Institutes of Ayurved...
# 2  - FAST-DS stands for Foreign Assets of Small T...
# 3  - First kartavya: to accelerate and sustain ec...
#
#                                            reference  faithfulness  \
# 0  The seven corridors are i) Mumbai-Pune, ii) Pu...           1.0
# ...

# %%
"""

1. without Reranker:
Metric	            Score	

Faithfulness	    97.2%	
Context Recall	    100%	
Answer Relevancy	90.5%	
Context Precision	65.4%

2. with Reranker:
Metric	            Score	

Faithfulness	    91.67%	
Context Recall	    100%	
Answer Relevancy	88.69%	
Context Precision	87.50%

3. Smart Filtering + Reranker
Metric	            Score	

Faithfulness	    92.50%	
Context Recall	    100%	
Answer Relevancy	87.91%	
Context Precision	90.97%

"""
# Out:
# '\n\nwithout Reranker:\nMetric\t            Score\t\n\nFaithfulness\t    97.2%\t\nContext Recall\t    100%\t\nAnswer Relevancy\t90.5%\t\nContext Precision\t65.4%\n\nwith Reranker:\nMetric\t            Score\t\n\nFaithfulness\t    91.67%\t\nContext Recall\t    100%\t\nAnswer Relevancy\t88.69%\t\nContext Precision\t87.50%\n\n'
