# %%
import pandas as pd

# %%
df=pd.read_csv("budget_rag_evaluation_report.csv")
df
# Out:
#                                            user_input  \
# 0   What has been the economic trajectory of India...
# 1   What is the government's 'Sankalp' mentioned i...
# 2   What are the three kartavyas that inspired the...
# 3   How many individuals have come out of multidim...
# 4   Which threefold approach is required for a sup...
# ..                                                ...
# 95  What is the proposed NCCD rate for Chewing tob...
# 96  What is the jurisdiction extension of the Cust...
# 97  What is the proposed change regarding the remo...
# 98  What is proposed regarding the merger of regis...
# 99  What is the proposal for the transition of bio...
#
#                                    retrieved_contexts  \
# 0   ['Budget 2026-2027 \n \nSpeech of \nNirmala Si...
# 1   ['Budget.  \n8. Our Government’s ‘Sankalp’ is ...
# 2   ['Budget.  \n8. Our Government’s ‘Sankalp’ is ...
# 3   ['Research Fund, and Research, Development and...
# ...

# %%
"""
test_set_size=5

llm=gpt-4o-mini:
1. without Reranker:
Metric	            Score	

Faithfulness	    97.2%	
Context Recall	    100%	
Answer Relevancy	90.5%	
Context Precision	65.4%

llm=gpt-5-nano:
2. with Reranker:
Metric	            Score	

Faithfulness	    91.67%	
Context Recall	    100%	
Answer Relevancy	88.69%	
Context Precision	87.50%

llm=gpt-5-nano:
3. Smart Filtering + Reranker + Prompt Engineering
Metric	            Score	

Faithfulness	    92.50%	
Context Recall	    100%	
Answer Relevancy	87.91%	
Context Precision	90.97%

llm=gpt-4o-mini:
4. Smart Filtering + Reranker + Prompt Engineering
Metric	            Score

Context Recall	    100%
Answer Relevancy	99.09%
Context Precision	95.83%
Faithfulness	    91.67%

"""

"""

test_set_size=100
llm=gpt-4o-mini:
Smart Filtering + Reranker + Prompt Engineering

Metric	            Score

Context Recall	    97.22%
Answer Relevancy	95.75%
Context Precision	95.8%
Faithfulness	    89.41%

"""
# Out:
# '\n\nllm=gpt-4o-mini:\n1. without Reranker:\nMetric\t            Score\t\n\nFaithfulness\t    97.2%\t\nContext Recall\t    100%\t\nAnswer Relevancy\t90.5%\t\nContext Precision\t65.4%\n\nllm=gpt-5-nano:\n2. with Reranker:\nMetric\t            Score\t\n\nFaithfulness\t    91.67%\t\nContext Recall\t    100%\t\nAnswer Relevancy\t88.69%\t\nContext Precision\t87.50%\n\nllm=gpt-5-nano:\n3. Smart Filtering + Reranker + Prompt Engineering\nMetric\t            Score\t\n\nFaithfulness\t    92.50%\t\nContext Recall\t    100%\t\nAnswer Relevancy\t87.91%\t\nContext Precision\t90.97%\n\nllm=gpt-4o-mini:\n4. Smart Filtering + Reranker + Prompt Engineering\nMetric\t            Score\n\nContext Recall\t    100%\nAnswer Relevancy\t99.09%\nContext Precision\t95.83%\nFaithfulness\t    91.67%\n\n\n'
